# %%
import pandas as pd

df = pd.read_parquet("/Users/max/Downloads/polymarket-data/snapshots.parquet")
print(df.head())
# Out:
#    id                       slug  \
# 0   1  btc-updown-15m-1778859900
# 1   2  btc-updown-15m-1778859900
# 2   3  btc-updown-15m-1778859900
# 3   4  btc-updown-15m-1778859900
# 4   5  btc-updown-15m-1778859900
#
#                                             token_id outcome  collected_ts  \
# 0  9048220664978319766199040015454254616287438384...      Up    1778860462
# 1  2339248283346129339934492869799114216761533186...    Down    1778860462
# 2  9048220664978319766199040015454254616287438384...      Up    1778860463
# 3  2339248283346129339934492869799114216761533186...    Down    1778860463
# 4  9048220664978319766199040015454254616287438384...      Up    1778860464
#
#                collected_utc book_timestamp  \
# 0  2026-05-15T15:54:22+00:00  1778860462184
# 1  2026-05-15T15:54:22+00:00  1778860462184
# 2  2026-05-15T15:54:23+00:00  1778860463130
# 3  2026-05-15T15:54:23+00:00  1778860463130
# 4  2026-05-15T15:54:24+00:00  1778860464255
#
# ...

# %%
import requests

url = "https://clob.polymarket.com/book"

response = requests.get(url)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import requests
#       2
#       3 url = "https://clob.polymarket.com/book"
#       4
#
# ModuleNotFoundError: No module named 'requests'
